# %% [markdown]
# ### load data

# %%
from pandas import read_pickle
path = r"C:\Users\tanch\Documents\NTU\NTU Year 4\Semester 1\CZ4041 - Machine Learning\Team Project\data\full_train2.pkl"
data = read_pickle(path)
X_cols = [col for col in data.columns if col not in ["card_id","target"]]
X, y = data[X_cols], data['target']

# %%
len(X.columns)
# Out:
# 424

# %%
import lightgbm as lgb
data = lgb.Dataset(X,y)

# %% [markdown]
# ### commence optuna

# %%
import optuna

# %%
def objective(trial):

    params = {
        "num_leaves": 193, # trial.suggest_int('num_leaves', 193, 200),
        "min_data_in_leaf": 325,
        "bagging_fraction": 0.9229024640381899, #trial.suggest_float("bagging_fraction", 0.69-0.3,0.69+0.3),
        "bagging_freq": 5, 
        "feature_fraction_bynode" : 0.5257141178498, # trial.suggest_float("feature_fraction_bynode", 0.45-0.3,0.45+0.3),
        "feature_fraction": 0.8016157141983071, # trial.suggest_float("feature_fraction", 0.56-0.3,0.56+0.3),
#         "min_gain_to_split": 0.05621632216128067,     
        "lambda_l1": trial.suggest_float("feature_fraction", 0.0001,0.01, log = True), # 0.00019163693019842484,
        "lambda_l2": trial.suggest_float("feature_fraction", 0.0001,0.01, log = True), # 0.0027009967266884796,   
        "learning_rate": 0.01,  # trial.suggest_float("learning_rate", 0.001,0.01), # 0.01051003661177018,
        
        "boosting": "gbdt",
        "extra_trees": False,
        "objective": "regression",
        "max_depth":  -1,
        "bagging_freq": 10  ,                  # resamples rows at every k-th iteration
        "max_bin": 255 ,                        # bins continuous values
#         "device_type":  "cuda",
        "force_col_wise":  True  ,                 # reduce memory cost
        "weight_column": ""
    }
    
    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "rmse")
    
    eval_hist  = lgb.cv(
        params = params, 
        train_set = data, 
        num_boost_round = 1000, 
        nfold=3, 
        metrics = ["rmse"],
        stratified = False, 
        categorical_feature = "auto",
        verbose_eval = 10,
        early_stopping_rounds = 10,
        callbacks  = [pruning_callback]
    )
    
    return min(eval_hist['rmse-mean'])

# %%
study = optuna.create_study(
    direction='minimize',                     
    sampler= None,          # use TPESampler if None
    pruner= None            # use median Sampler if None
)
study.optimize(objective, n_trials=30)
# Out:
# [I 2022-10-24 20:30:17,833] A new study created in memory with name: no-name-8f12edbc-bf1c-4450-847e-9297110f8a1c
# C:\Users\tanch\anaconda3\envs\ml\lib\site-packages\lightgbm\engine.py:577: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Start training from score -0.399389
# C:\Users\tanch\anaconda3\envs\ml\lib\site-packages\lightgbm\engine.py:620: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Start training from score -0.396838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	cv_agg's rmse: 3.82792 + 0.0587955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	cv_agg's rmse: 3.80914 + 0.0587537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	cv_agg's rmse: 3.79184 + 0.0586938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	cv_agg's rmse: 3.77768 + 0.0585404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	cv_agg's rmse: 3.76484 + 0.0588841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	cv_agg's rmse: 3.75413 + 0.0586423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	cv_agg's rmse: 3.74491 + 0.058246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	cv_agg's rmse: 3.73681 + 0.0586988
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	cv_agg's rmse: 3.73008 + 0.0585072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	cv_agg's rmse: 3.7236 + 0.0582412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	cv_agg's rmse: 3.71823 + 0.0583159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	cv_agg's rmse: 3.71359 + 0.0583337
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	cv_agg's rmse: 3.70912 + 0.0582297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	cv_agg's rmse: 3.70577 + 0.0582397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	cv_agg's rmse: 3.70247 + 0.0583013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	cv_agg's rmse: 3.69972 + 0.0585665
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	cv_agg's rmse: 3.69677 + 0.0584106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	cv_agg's rmse: 3.69422 + 0.0582126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	cv_agg's rmse: 3.69216 + 0.0580463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	cv_agg's rmse: 3.69032 + 0.057769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Start training from score -0.396838
# [I 2022-10-24 22:09:57,476] Trial 40 pruned. Trial was pruned at iteration 0.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Info] Start training from score -0.396838
# [10]	cv_agg's rmse: 3.82346 + 0.0585533
# [20]	cv_agg's rmse: 3.80097 + 0.0583375
# [30]	cv_agg's rmse: 3.78164 + 0.0583153
# [40]	cv_agg's rmse: 3.76518 + 0.0583862
# [50]	cv_agg's rmse: 3.75112 + 0.0581621
# [60]	cv_agg's rmse: 3.73917 + 0.0580814
# [70]	cv_agg's rmse: 3.72924 + 0.0577166
# [80]	cv_agg's rmse: 3.72059 + 0.0575342
# [90]	cv_agg's rmse: 3.71322 + 0.0574358
# [100]	cv_agg's rmse: 3.70673 + 0.0571139
# [110]	cv_agg's rmse: 3.70121 + 0.0570825
# [120]	cv_agg's rmse: 3.69637 + 0.0570418
# [130]	cv_agg's rmse: 3.69247 + 0.0565325
# [140]	cv_agg's rmse: 3.68873 + 0.0563412
# [150]	cv_agg's rmse: 3.68535 + 0.0561608
# [160]	cv_agg's rmse: 3.68249 + 0.0560906
# [170]	cv_agg's rmse: 3.67988 + 0.056021
# [180]	cv_agg's rmse: 3.67783 + 0.0561094
# [190]	cv_agg's rmse: 3.67596 + 0.0558844
# [200]	cv_agg's rmse: 3.67431 + 0.0558266
# [210]	cv_agg's rmse: 3.67277 + 0.0559024
# [220]	cv_agg's rmse: 3.67149 + 0.0557291
# [230]	cv_agg's rmse: 3.67032 + 0.0556615
# [240]	cv_agg's rmse: 3.66925 + 0.0556575
# [250]	cv_agg's rmse: 3.66823 + 0.055479
# [260]	cv_agg's rmse: 3.66722 + 0.0553612
# [270]	cv_agg's rmse: 3.66652 + 0.0554279
# [280]	cv_agg's rmse: 3.66586 + 0.0553869
# [290]	cv_agg's rmse: 3.66528 + 0.0554982
# [300]	cv_agg's rmse: 3.6648 + 0.0555413
# [310]	cv_agg's rmse: 3.66413 + 0.055274
# [320]	cv_agg's rmse: 3.66366 + 0.0552512
# [330]	cv_agg's rmse: 3.66318 + 0.0552545
# [340]	cv_agg's rmse: 3.66271 + 0.0551171
# [350]	cv_agg's rmse: 3.66225 + 0.0550562
# [360]	cv_agg's rmse: 3.66193 + 0.0549533
# [370]	cv_agg's rmse: 3.66183 + 0.054968
# [380]	cv_agg's rmse: 3.66141 + 0.0549143
# [390]	cv_agg's rmse: 3.66115 + 0.0548534
# [400]	cv_agg's rmse: 3.661 + 0.054767
# [410]	cv_agg's rmse: 3.66084 + 0.0547697
# [420]	cv_agg's rmse: 3.66068 + 0.0547097
# [I 2022-10-24 22:14:53,390] Trial 41 pruned. Trial was pruned at iteration 420.
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Info] Start training from score -0.396838
# [10]	cv_agg's rmse: 3.82324 + 0.0584876
# [20]	cv_agg's rmse: 3.80048 + 0.0582926
# [30]	cv_agg's rmse: 3.78109 + 0.0583233
# [40]	cv_agg's rmse: 3.76445 + 0.0584041
# [50]	cv_agg's rmse: 3.75055 + 0.0584306
# [60]	cv_agg's rmse: 3.73866 + 0.0580409
# [70]	cv_agg's rmse: 3.7287 + 0.0579504
# [80]	cv_agg's rmse: 3.71996 + 0.0577419
# [90]	cv_agg's rmse: 3.71257 + 0.0575226
# [100]	cv_agg's rmse: 3.70619 + 0.0571982
# [110]	cv_agg's rmse: 3.70059 + 0.0571441
# [120]	cv_agg's rmse: 3.69591 + 0.0571611
# [130]	cv_agg's rmse: 3.69174 + 0.0568337
# [140]	cv_agg's rmse: 3.6881 + 0.0567552
# [150]	cv_agg's rmse: 3.68477 + 0.0568749
# [160]	cv_agg's rmse: 3.68215 + 0.0566478
# [170]	cv_agg's rmse: 3.67963 + 0.0568228
# [180]	cv_agg's rmse: 3.67757 + 0.0569261
# [190]	cv_agg's rmse: 3.67572 + 0.0568715
# [200]	cv_agg's rmse: 3.67406 + 0.0566506
# [210]	cv_agg's rmse: 3.67267 + 0.0564842
# [220]	cv_agg's rmse: 3.67118 + 0.0563601
# [230]	cv_agg's rmse: 3.66993 + 0.0561519
# [240]	cv_agg's rmse: 3.6689 + 0.0561709
# [250]	cv_agg's rmse: 3.66803 + 0.0561843
# [260]	cv_agg's rmse: 3.66703 + 0.0560161
# [270]	cv_agg's rmse: 3.66639 + 0.0559136
# [280]	cv_agg's rmse: 3.6656 + 0.0558154
# [290]	cv_agg's rmse: 3.66497 + 0.0558275
# [300]	cv_agg's rmse: 3.66423 + 0.0557722
# [310]	cv_agg's rmse: 3.66356 + 0.0555141
# [320]	cv_agg's rmse: 3.66304 + 0.055515
# [330]	cv_agg's rmse: 3.66267 + 0.0553714
# [340]	cv_agg's rmse: 3.6623 + 0.0552305
# [350]	cv_agg's rmse: 3.66202 + 0.0552727
# [360]	cv_agg's rmse: 3.6617 + 0.0552493
# [370]	cv_agg's rmse: 3.66145 + 0.0553251
# [380]	cv_agg's rmse: 3.66122 + 0.055276
# [390]	cv_agg's rmse: 3.66099 + 0.0551834
# [400]	cv_agg's rmse: 3.66081 + 0.0552057
# [410]	cv_agg's rmse: 3.66072 + 0.0552079
# [420]	cv_agg's rmse: 3.66057 + 0.0552367
# [430]	cv_agg's rmse: 3.66032 + 0.0551361
# [440]	cv_agg's rmse: 3.6602 + 0.0551908
# [450]	cv_agg's rmse: 3.66006 + 0.055196
# [460]	cv_agg's rmse: 3.65994 + 0.0551892
# [470]	cv_agg's rmse: 3.6599 + 0.0551855
# [480]	cv_agg's rmse: 3.65987 + 0.0553146
# [I 2022-10-24 22:20:47,128] Trial 42 finished with value: 3.6598271440131085 and parameters: {'bagging_fraction': 0.9388491476233931, 'feature_fraction_bynode': 0.5455380797125178, 'feature_fraction': 0.8316989392088208}. Best is trial 25 with value: 3.658712467143704.
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Info] Start training from score -0.396838
# [I 2022-10-24 22:20:48,489] Trial 43 pruned. Trial was pruned at iteration 0.
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Info] Start training from score -0.396838
# [I 2022-10-24 22:20:50,162] Trial 44 pruned. Trial was pruned at iteration 0.
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Info] Start training from score -0.396838
# [10]	cv_agg's rmse: 3.82332 + 0.0583584
# [20]	cv_agg's rmse: 3.80088 + 0.0582255
# [30]	cv_agg's rmse: 3.78121 + 0.0580908
# [40]	cv_agg's rmse: 3.7648 + 0.0579942
# [50]	cv_agg's rmse: 3.75072 + 0.0579898
# [60]	cv_agg's rmse: 3.73869 + 0.058016
# [70]	cv_agg's rmse: 3.7284 + 0.0577708
# [80]	cv_agg's rmse: 3.71974 + 0.0576606
# [90]	cv_agg's rmse: 3.71234 + 0.0574593
# [100]	cv_agg's rmse: 3.70601 + 0.057498
# [110]	cv_agg's rmse: 3.70049 + 0.057406
# [120]	cv_agg's rmse: 3.69569 + 0.0571384
# [130]	cv_agg's rmse: 3.69149 + 0.057051
# [140]	cv_agg's rmse: 3.68798 + 0.0567989
# [150]	cv_agg's rmse: 3.68483 + 0.0567241
# [160]	cv_agg's rmse: 3.68213 + 0.0565479
# [170]	cv_agg's rmse: 3.67972 + 0.0566182
# [180]	cv_agg's rmse: 3.67756 + 0.0566478
# [190]	cv_agg's rmse: 3.67576 + 0.0565068
# [200]	cv_agg's rmse: 3.67404 + 0.0564041
# [210]	cv_agg's rmse: 3.67239 + 0.0563656
# [220]	cv_agg's rmse: 3.67112 + 0.0561632
# [230]	cv_agg's rmse: 3.67005 + 0.0561965
# [240]	cv_agg's rmse: 3.669 + 0.0561617
# [250]	cv_agg's rmse: 3.66801 + 0.056162
# [260]	cv_agg's rmse: 3.6671 + 0.0560465
# [270]	cv_agg's rmse: 3.66629 + 0.0559841
# [280]	cv_agg's rmse: 3.66557 + 0.0559456
# [290]	cv_agg's rmse: 3.66494 + 0.0558415
# [300]	cv_agg's rmse: 3.66429 + 0.0557398
# [310]	cv_agg's rmse: 3.66364 + 0.0556786
# [320]	cv_agg's rmse: 3.66316 + 0.0554791
# [330]	cv_agg's rmse: 3.66267 + 0.0553359
# [340]	cv_agg's rmse: 3.66208 + 0.0552444
# [350]	cv_agg's rmse: 3.66171 + 0.0553245
# [360]	cv_agg's rmse: 3.66137 + 0.0553885
# [370]	cv_agg's rmse: 3.6611 + 0.055299
# [380]	cv_agg's rmse: 3.66087 + 0.0551543
# [390]	cv_agg's rmse: 3.66054 + 0.0552201
# [400]	cv_agg's rmse: 3.66028 + 0.0550888
# [410]	cv_agg's rmse: 3.66009 + 0.0549246
# [420]	cv_agg's rmse: 3.65985 + 0.0547711
# [430]	cv_agg's rmse: 3.6597 + 0.0547923
# [440]	cv_agg's rmse: 3.65961 + 0.0547707
# [450]	cv_agg's rmse: 3.65944 + 0.0547346
# [460]	cv_agg's rmse: 3.6593 + 0.0547801
# [470]	cv_agg's rmse: 3.65921 + 0.0548743
# [480]	cv_agg's rmse: 3.6591 + 0.0549508
# [490]	cv_agg's rmse: 3.659 + 0.0549491
# [500]	cv_agg's rmse: 3.65897 + 0.0549666
# [510]	cv_agg's rmse: 3.65884 + 0.0550271
# [520]	cv_agg's rmse: 3.65874 + 0.0549225
# [530]	cv_agg's rmse: 3.65877 + 0.0548525
# [I 2022-10-24 22:27:11,410] Trial 45 finished with value: 3.658716841572574 and parameters: {'bagging_fraction': 0.9717372536732277, 'feature_fraction_bynode': 0.5526069013602205, 'feature_fraction': 0.8000126031544813}. Best is trial 25 with value: 3.658712467143704.
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Info] Start training from score -0.396838
# [I 2022-10-24 22:27:13,060] Trial 46 pruned. Trial was pruned at iteration 0.
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Info] Start training from score -0.396838
# [10]	cv_agg's rmse: 3.8234 + 0.0584271
# [20]	cv_agg's rmse: 3.80033 + 0.0583834
# [30]	cv_agg's rmse: 3.78093 + 0.0583724
# [40]	cv_agg's rmse: 3.76425 + 0.0580907
# [50]	cv_agg's rmse: 3.75025 + 0.0579477
# [60]	cv_agg's rmse: 3.73809 + 0.0576428
# [70]	cv_agg's rmse: 3.72788 + 0.0576085
# [80]	cv_agg's rmse: 3.71896 + 0.0575216
# [90]	cv_agg's rmse: 3.71149 + 0.0572062
# [100]	cv_agg's rmse: 3.70508 + 0.0570049
# [110]	cv_agg's rmse: 3.69943 + 0.0567904
# [120]	cv_agg's rmse: 3.69477 + 0.0567424
# [130]	cv_agg's rmse: 3.69073 + 0.0565641
# [140]	cv_agg's rmse: 3.68716 + 0.0564106
# [150]	cv_agg's rmse: 3.68402 + 0.0563199
# [160]	cv_agg's rmse: 3.68124 + 0.056236
# [170]	cv_agg's rmse: 3.6789 + 0.0560134
# [180]	cv_agg's rmse: 3.67674 + 0.0559021
# [190]	cv_agg's rmse: 3.67484 + 0.0558014
# [200]	cv_agg's rmse: 3.67334 + 0.0557807
# [210]	cv_agg's rmse: 3.67193 + 0.0557195
# [220]	cv_agg's rmse: 3.67069 + 0.0556937
# [230]	cv_agg's rmse: 3.66941 + 0.0555994
# [240]	cv_agg's rmse: 3.6684 + 0.0554438
# [250]	cv_agg's rmse: 3.66751 + 0.0554416
# [260]	cv_agg's rmse: 3.6667 + 0.0552104
# [270]	cv_agg's rmse: 3.66593 + 0.0551059
# [280]	cv_agg's rmse: 3.66522 + 0.0550814
# [290]	cv_agg's rmse: 3.66449 + 0.0550596
# [300]	cv_agg's rmse: 3.66394 + 0.0549842
# [310]	cv_agg's rmse: 3.66332 + 0.0549533
# [320]	cv_agg's rmse: 3.66272 + 0.0548123
# [330]	cv_agg's rmse: 3.66236 + 0.0547336
# [340]	cv_agg's rmse: 3.66187 + 0.0546977
# [350]	cv_agg's rmse: 3.66154 + 0.0545694
# [360]	cv_agg's rmse: 3.66121 + 0.0545226
# [370]	cv_agg's rmse: 3.66092 + 0.054514
# [380]	cv_agg's rmse: 3.66064 + 0.0544936
# [390]	cv_agg's rmse: 3.66028 + 0.0544695
# [400]	cv_agg's rmse: 3.66014 + 0.0544441
# [410]	cv_agg's rmse: 3.65998 + 0.0544273
# [420]	cv_agg's rmse: 3.65973 + 0.0544239
# [430]	cv_agg's rmse: 3.65954 + 0.0544822
# [440]	cv_agg's rmse: 3.65936 + 0.0545489
# [450]	cv_agg's rmse: 3.65923 + 0.0544974
# [460]	cv_agg's rmse: 3.65915 + 0.0546495
# [470]	cv_agg's rmse: 3.65906 + 0.0546342
# [480]	cv_agg's rmse: 3.65909 + 0.0545834
# [I 2022-10-24 22:33:29,534] Trial 47 finished with value: 3.659023371590118 and parameters: {'bagging_fraction': 0.9879892414851295, 'feature_fraction_bynode': 0.546337454464385, 'feature_fraction': 0.8590449663565511}. Best is trial 25 with value: 3.658712467143704.
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Info] Start training from score -0.396838
# [10]	cv_agg's rmse: 3.82315 + 0.0584066
# [20]	cv_agg's rmse: 3.8003 + 0.0581639
# [30]	cv_agg's rmse: 3.78077 + 0.0582376
# [40]	cv_agg's rmse: 3.76437 + 0.0581495
# [50]	cv_agg's rmse: 3.75031 + 0.0579635
# [60]	cv_agg's rmse: 3.73845 + 0.0579719
# [70]	cv_agg's rmse: 3.72817 + 0.0580097
# [80]	cv_agg's rmse: 3.71942 + 0.0579958
# [90]	cv_agg's rmse: 3.7119 + 0.0578323
# [100]	cv_agg's rmse: 3.70549 + 0.0579246
# [110]	cv_agg's rmse: 3.69986 + 0.0577531
# [120]	cv_agg's rmse: 3.69515 + 0.0576165
# [130]	cv_agg's rmse: 3.6912 + 0.0575165
# [140]	cv_agg's rmse: 3.68765 + 0.0574462
# [150]	cv_agg's rmse: 3.68449 + 0.0573077
# [160]	cv_agg's rmse: 3.68203 + 0.0570929
# [170]	cv_agg's rmse: 3.67976 + 0.0569062
# [180]	cv_agg's rmse: 3.67767 + 0.0569368
# [190]	cv_agg's rmse: 3.67591 + 0.0568562
# [200]	cv_agg's rmse: 3.67427 + 0.0568021
# [210]	cv_agg's rmse: 3.67276 + 0.0568852
# [220]	cv_agg's rmse: 3.67157 + 0.0566104
# [230]	cv_agg's rmse: 3.67034 + 0.0564462
# [240]	cv_agg's rmse: 3.66938 + 0.056351
# [I 2022-10-24 22:36:32,394] Trial 48 pruned. Trial was pruned at iteration 248.
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Total Bins 80720
# [LightGBM] [Info] Number of data points in the train set: 134610, number of used features: 424
# [LightGBM] [Info] Start training from score -0.384681
# [LightGBM] [Info] Start training from score -0.399389
# [LightGBM] [Info] Start training from score -0.396838
# [10]	cv_agg's rmse: 3.82318 + 0.0585755
# [20]	cv_agg's rmse: 3.80041 + 0.0586129
# [30]	cv_agg's rmse: 3.78154 + 0.0583041
# [40]	cv_agg's rmse: 3.76486 + 0.0586676
# [50]	cv_agg's rmse: 3.75077 + 0.0587965
# [60]	cv_agg's rmse: 3.73888 + 0.0585997
# [70]	cv_agg's rmse: 3.72877 + 0.0584414
# [80]	cv_agg's rmse: 3.72004 + 0.0583469
# [90]	cv_agg's rmse: 3.71274 + 0.0578897
# [100]	cv_agg's rmse: 3.7064 + 0.0578199
# [110]	cv_agg's rmse: 3.70071 + 0.0575721
# [120]	cv_agg's rmse: 3.69601 + 0.0573706
# [130]	cv_agg's rmse: 3.69194 + 0.0569805
# [140]	cv_agg's rmse: 3.6883 + 0.0568394
# [150]	cv_agg's rmse: 3.68514 + 0.0567125
# [160]	cv_agg's rmse: 3.68231 + 0.0566529
# [170]	cv_agg's rmse: 3.68005 + 0.056527
# [I 2022-10-24 22:38:43,549] Trial 49 pruned. Trial was pruned at iteration 179.

# %%
study.best_trial.params, study.best_trial.value
# Out:
# ({'bagging_fraction': 0.9229024640381899,
#   'feature_fraction_bynode': 0.5257141178498,
#   'feature_fraction': 0.8016157141983071},
#  3.658712467143704)

# %%
({'bagging_fraction': 0.9229024640381899,
  'feature_fraction_bynode': 0.5257141178498,
  'feature_fraction': 0.8016157141983071},
 3.658712467143704)

# %%
params = {
        "num_leaves": trial.suggest_int('num_leaves', 100, 200),
        "min_data_in_leaf": 325,
        "bagging_fraction": 0.6909615826257344, # trial.suggest_float("bagging_fraction", 0.55,0.8),
        "bagging_freq": 5, # trial.suggest_int("bagging_freq", 4,6),
        "feature_fraction_bynode" :0.4540787460650182, # trial.suggest_float("feature_fraction_bynode", 0.45-0.3,0.45+0.3),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.56-0.3,0.56+0.3),
        "min_gain_to_split": 0.05621632216128067,     
        "lambda_l1": 0.00019163693019842484,
        "lambda_l2": 0.0027009967266884796,   
        "learning_rate": 0.05,  # trial.suggest_float("learning_rate", 0.001,0.01), # 0.01051003661177018,
        
        "boosting": "gbdt",
        "extra_trees": False,
        "objective": "regression",
        "max_depth":  -1,
        "bagging_freq": 10  ,                  # resamples rows at every k-th iteration
        "max_bin": 255 ,                        # bins continuous values
#         "device_type":  "cuda",
        "force_col_wise":  True  ,                 # reduce memory cost
        "weight_column": ""
    }
