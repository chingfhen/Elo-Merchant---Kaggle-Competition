# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt
path = r"C:\Users\tanch\Documents\NTU\NTU Year 4\Semester 1\CZ4041 - Machine Learning\Team Project\results\node2vec_embeddings.csv"
results = pd.read_csv(path)
results_long = pd.melt(results, id_vars = ["type","id_column","embedding_dimension"], value_vars = ["train_r2","test_r2","train_root_mean_squared_error","test_root_mean_squared_error"])
results_long
# Out:
#                                          type    id_column  \
# 0                                    baseline  merchant_id
# 1                    baseline_with_embeddings  merchant_id
# 2                   baseline_with_id_features  merchant_id
# 3    baseline_with_embeddings_and_id_features  merchant_id
# 4                                    baseline      city_id
# ..                                        ...          ...
# 123  baseline_with_embeddings_and_id_features      city_id
# 124                                  baseline     state_id
# 125                  baseline_with_embeddings     state_id
# 126                 baseline_with_id_features     state_id
# 127  baseline_with_embeddings_and_id_features     state_id
#
#      embedding_dimension                      variable     value
# 0                     16                      train_r2  0.000166
# 1                     16                      train_r2  0.000816
# ...

# %%
def process_data(data, id_column, metrics):
    temp = data
    temp = temp[temp["id_column"] == id_column]
    temp = temp[temp["variable"].isin(metrics)]
    return temp

# %% [markdown]
# # merchant_id

# %%
metric = "R_Square"
x_ticks = ['baseline','+embeddings','+id_features','+all']
temp = process_data(results_long, "merchant_id", ["train_r2","test_r2"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "type", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1,2,3]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
# Out:
# [Text(0, 0.5, 'R_Square'), Text(0.5, 0, '')]

# %%
metric = "RMSE"
x_ticks = ['baseline','+embeddings','+id_features','+all']
temp = process_data(results_long, "merchant_id", ["train_root_mean_squared_error","test_root_mean_squared_error"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "type", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1,2,3]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
g.set_ylim(temp.value.min()-temp.value.std(), temp.value.max()+ temp.value.std())
# Out:
# (3.837266633362154, 3.853671280106299)

# %% [markdown]
# # merchant_category_id

# %%
metric = "R_Square"
x_ticks = ['baseline','+embeddings','+id_features','+all']
temp = process_data(results_long, "merchant_category_id", ["train_r2","test_r2"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "type", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1,2,3]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
# Out:
# [Text(0, 0.5, 'R_Square'), Text(0.5, 0, '')]

# %%
metric = "RMSE"
x_ticks = ['baseline','+embeddings','+id_features','+all']
temp = process_data(results_long, "merchant_category_id", ["train_root_mean_squared_error","test_root_mean_squared_error"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "type", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1,2,3]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
g.set_ylim(temp.value.min()-temp.value.std(), temp.value.max()+ temp.value.std())
# Out:
# (3.832699883982066, 3.8545571130256118)

# %% [markdown]
# # city_id

# %%
metric = "R_Square"
x_ticks = ['baseline','+embeddings','+id_features','+all']
temp = process_data(results_long, "city_id", ["train_r2","test_r2"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "type", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1,2,3]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
# Out:
# [Text(0, 0.5, 'R_Square'), Text(0.5, 0, '')]

# %%
metric = "RMSE"
x_ticks = ['baseline','+embeddings','+id_features','+all']
temp = process_data(results_long, "city_id", ["train_root_mean_squared_error","test_root_mean_squared_error"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "type", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1,2,3]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
g.set_ylim(temp.value.min()-temp.value.std(), temp.value.max()+ temp.value.std())
# Out:
# (3.837325598307575, 3.8533988711852016)

# %% [markdown]
# # state_id

# %%
metric = "R_Square"
x_ticks = ['baseline','+embeddings','+id_features','+all']
temp = process_data(results_long, "state_id", ["train_r2","test_r2"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "type", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1,2,3]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
# Out:
# [Text(0, 0.5, 'R_Square'), Text(0.5, 0, '')]

# %%
metric = "RMSE"
x_ticks = ['baseline','+embeddings','+id_features','+all']
temp = process_data(results_long, "state_id", ["train_root_mean_squared_error","test_root_mean_squared_error"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "type", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1,2,3]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
g.set_ylim(temp.value.min()-temp.value.std(), temp.value.max()+ temp.value.std())
# Out:
# (3.834571009713135, 3.854015341814928)

# %% [markdown]
# ## dimensions

# %%
def process_data(data, id_column, metrics, typee = None):
    temp = data
    temp = temp[temp["id_column"].isin(id_column)]
    temp = temp[temp["variable"].isin(metrics)]
    if typee:
        temp = temp[temp["type"].isin(typee)]
    return temp

# %%
metric = "RMSE"
x_ticks = ["16","8"]
temp = process_data(results_long, ['state_id'], ["train_root_mean_squared_error","test_root_mean_squared_error"], typee = ["baseline_with_embeddings"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "embedding_dimension", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = "embedding_dimension")
g.set_ylim(temp.value.min()-temp.value.std(), temp.value.max()+ temp.value.std())
# Out:
# (3.842608807832703, 3.850336904167297)

# %%
metric = "RMSE"
x_ticks = ["16","8"]
temp = process_data(results_long, ['merchant_id'], ["train_root_mean_squared_error","test_root_mean_squared_error"], typee = ["baseline_with_embeddings"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "embedding_dimension", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = "embedding_dimension")
g.set_ylim(temp.value.min()-temp.value.std(), temp.value.max()+ temp.value.std())
# Out:
# (3.848377784433189, 3.850611138435223)

# %%
metric = "RMSE"
x_ticks = ["16","8"]
temp = process_data(results_long, ['city_id'], ["train_root_mean_squared_error","test_root_mean_squared_error"], typee = ["baseline_with_embeddings"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "embedding_dimension", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = "embedding_dimension")
g.set_ylim(temp.value.min()-temp.value.std(), temp.value.max()+ temp.value.std())
# Out:
# (3.8437126346965713, 3.8507109056966926)

# %%
metric = "RMSE"
x_ticks = ["16","8"]
temp = process_data(results_long, ['merchant_category_id'], ["train_root_mean_squared_error","test_root_mean_squared_error"], typee = ["baseline_with_embeddings"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "embedding_dimension", palette = "Accent_r")
g.legend(title=None)
g.set_xticks([0,1]) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = "embedding_dimension")
g.set_ylim(temp.value.min()-temp.value.std(), temp.value.max()+ temp.value.std())
# Out:
# (3.8386416582254346, 3.85135821767976)

# %%
metric = "R_Square"
x_ticks = ["16","8"]
temp = process_data(results_long, ['state_id'], ["train_r2", "test_r2"], typee = ["baseline_with_embeddings"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "embedding_dimension", palette = "Accent_r")
g.legend(title=None)
g.set_xticks(range(len(x_ticks))) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
# Out:
# [Text(0, 0.5, 'R_Square'), Text(0.5, 0, '')]

# %%
metric = "R_Square"
x_ticks = ["16","8"]
temp = process_data(results_long, ['city_id'], ["train_r2", "test_r2"], typee = ["baseline_with_embeddings"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "embedding_dimension", palette = "Accent_r")
g.legend(title=None)
g.set_xticks(range(len(x_ticks))) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
# Out:
# [Text(0, 0.5, 'R_Square'), Text(0.5, 0, '')]

# %%
metric = "R_Square"
x_ticks = ["16","8"]
temp = process_data(results_long, ['city_id'], ["train_r2", "test_r2"], typee = ["baseline_with_embeddings"])
g = sb.barplot(data = temp,  y = "value", hue = "variable", x = "embedding_dimension", palette = "Accent_r")
g.legend(title=None)
g.set_xticks(range(len(x_ticks))) # <--- set the ticks first
g.set_xticklabels(x_ticks)
g.set(ylabel = metric, xlabel = None)
# Out:
#                         type             id_column  embedding_dimension  \
# 1   baseline_with_embeddings           merchant_id                   16
# 5   baseline_with_embeddings               city_id                   16
# 9   baseline_with_embeddings  merchant_category_id                   16
# 13  baseline_with_embeddings              state_id                   16
# 17  baseline_with_embeddings           merchant_id                    8
# 21  baseline_with_embeddings  merchant_category_id                    8
# 25  baseline_with_embeddings               city_id                    8
# 29  baseline_with_embeddings              state_id                    8
# 33  baseline_with_embeddings           merchant_id                   16
# 37  baseline_with_embeddings               city_id                   16
# 41  baseline_with_embeddings  merchant_category_id                   16
# 45  baseline_with_embeddings              state_id                   16
# ...

# %%
temp
# Out:
# Empty DataFrame
# Columns: [type, id_column, embedding_dimension, variable, value]
# Index: []

# %%
temp
# Out:
#                                         type    id_column  \
# 32                                  baseline  merchant_id
# 33                  baseline_with_embeddings  merchant_id
# 34                 baseline_with_id_features  merchant_id
# 35  baseline_with_embeddings_and_id_features  merchant_id
# 48                                  baseline  merchant_id
# 49                  baseline_with_embeddings  merchant_id
# 50                 baseline_with_id_features  merchant_id
# 51  baseline_with_embeddings_and_id_features  merchant_id
#
#     embedding_dimension variable     value
# 32                   16  test_r2  0.000139
# 33                   16  test_r2  0.000185
# 34                   16  test_r2  0.002315
# 35                   16  test_r2  0.002415
# 48                    8  test_r2  0.000139
# 49                    8  test_r2  0.000124
# 50                    8  test_r2  0.002315
# 51                    8  test_r2  0.002320
